# %% [markdown]
# # Exploration des données (découvertes)

# %%
import pandas
df = pandas.read_table('../data/didascalies.csv', ',')

# %%
df.head()
# Out:
#    id  seance_id        date moment type                            titre  \
# 0   1          1  2017-06-27  15:00  loi                              NaN
# 1   2          1  2017-06-27  15:00  loi                              NaN
# 2   3          1  2017-06-27  15:00  loi  ouverture de la xve législature
# 3   4          1  2017-06-27  15:00  loi  ouverture de la xve législature
# 4   5          1  2017-06-27  15:00  loi     constitution du bureau d'âge
#
#                      titre_complet  timestamp  \
# 0                              NaN         20
# 1                              NaN         30
# 2  ouverture de la xve législature         60
# 3  ouverture de la xve législature         70
# 4     constitution du bureau d'âge         80
#
#                                         intervention  nb_mots  nom  \
# 0                      <p>La séance est ouverte.</p>        7  NaN
# 1      <p>La séance est ouverte à quinze heures.</p>        9  NaN
# 2             <p>Ouverture de la XVe législature</p>        8  NaN
# 3  <p>Je déclare ouverte la XVe législature de l'...       14  NaN
# 4                <p>constitution du bureau d'âge</p>        7  NaN
#
#       parlementaire sexe parlementaire_groupe_acronyme  \
# 0  Bernard Brochand    H                            NI
# 1               NaN  NaN                           NaN
# 2               NaN  NaN                           NaN
# 3  Bernard Brochand    H                            NI
# 4               NaN  NaN                           NaN
#
#                  fonction                                             source
# 0  président, doyen d'âge  http://www.assemblee-nationale.fr/15/cri/2016-...
# 1                     NaN  http://www.assemblee-nationale.fr/15/cri/2016-...
# 2                     NaN  http://www.assemblee-nationale.fr/15/cri/2016-...
# 3  président, doyen d'âge  http://www.assemblee-nationale.fr/15/cri/2016-...
# 4                     NaN  http://www.assemblee-nationale.fr/15/cri/2016-...

# %%
from vega import VegaLite

# %%
VegaLite({
  "mark": "point",
  "encoding": {
    "y": {"type": "quantitative", "field": "Acceleration"},
    "x": {"type": "quantitative", "field": "Horsepower"},
    "color": {"type": "quantitative", "field": "Horsepower"},
    "tooltip": [
        {"type": "quantitative", "field": "Acceleration"},
        {"type": "quantitative", "field": "Horsepower"}
    ]
  }
}, df)
# Out:
# <div class="vega-embed" id="d7f031c0-12a9-4a4c-b644-dc59ae4024a3"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
