# %%
import pandas
df = pandas.read_table('~/Desktop/lfdll/data/didascalies.csv', ',')

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

def top_reaction(data, col, keyword, speaker):
    if col == "didascalie":
        diz={"parlementaire":"nom", "nom":"parlementaire"}
        filterd_d = data[(data[diz[speaker]].isnull())]
        d = filterd_d.copy()
        d[col] = d[col].str.lower()
        dat = d[d[col].str.contains(keyword)==True]
        print dat.shape
        co = dat[speaker].value_counts()
    else:
        diz={"parlementaire":"nom", "nom":"parlementaire"}
        filterd_d = data[(data[diz[speaker]].isnull())]
        d = filterd_d.copy()
        d[col] = d[col].str.lower()
        dat = d[d[col].str.contains(keyword)==True]
        print dat.shape
        co = dat[speaker].value_counts()
    return co

# %%
top_reaction(df,"didascalie","applaud","nom").plot(kind='barh',figsize=(10,10))
# Out:
# (3451, 20)

# %%
top_reaction(df,"didascalie","rire","nom").plot(kind='barh',figsize=(10,10))
# Out:
# (495, 20)

# %%
top_reaction(df,"didascalie","applaud","parlementaire").plot(kind='barh',figsize=(10,100))
# Out:
# (11761, 20)

# %%
top_reaction(df,"didascalie","rire","parlementaire").plot(kind='barh',figsize=(10,100))
# Out:
# (2046, 20)

# %%
top_reaction(df,"ton","positif","nom").plot(kind='barh',figsize=(10,10))
# Out:
# (3808, 20)

# %%
top_reaction(df,"ton","negatif","nom").plot(kind='barh',figsize=(10,10))
# Out:
# (1099, 20)

# %%
top_reaction(df,"ton","positif","parlementaire").plot(kind='barh',figsize=(10,100))
# Out:
# (13166, 20)

# %%
top_reaction(df,"didascalie","rappel","parlementaire").plot(kind='barh',figsize=(10,100))
# Out:
# (275, 20)
